# %% [markdown]
# # install snscrape packages

# %%
# !pip3 install snscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import snscrape.modules.twitter

# %% [markdown]
# # query #stopasianhate tweets

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#stopasianhate since:2021-03-15 until:2022-01-01 min_faves:3 exclude:retweets','corona lang:en').get_items()):
    tweets_list.append([tweet.date,  tweet.content]) #tweet.id
tweets_list
# Out:
# [[datetime.datetime(2021, 12, 31, 23, 27, 51, tzinfo=datetime.timezone.utc),
#   'What an amazing year for the #AAPI community. Thank you @taaforg @smarcelo @baomnguyen @iammcjin @toda @joetsai1999 #stopasianhate #seeusunite #asianamerican @estmedia https://t.co/CSnxAS2KJ9'],
#  [datetime.datetime(2021, 12, 31, 22, 49, 25, tzinfo=datetime.timezone.utc),
#   "@kevskewl @philanderwicks @Charlen98749545 @Sc0ttSDr3d @GryKngBlakState @RobinGr08124639 @CLARETHAWOODS @Haki_Shakur @MalcolmXScholar @CatherinesYoun1 @casrule @ReeseWard19 @BlackGeniusKing @MarleyK20 @redz001DC @Michael00181389 @MsKweet @SonMemphis @OmgRising @ARTESIA13 @quirkiebird @djassassinpgh @indigenoussista @YouTube @PGRNA California Asian man arrested in Iowa allegedly had 'hit list' including Biden &amp; Obama... \n#StopAsianHateN #StopAsianHate\nhttps://t.co/icUvW2gmIn via @YouTube"],
#  [datetime.datetime(2021, 12, 31, 22, 28, 16, tzinfo=datetime.timezone.utc),
# ...

# %%
result= pd.DataFrame(tweets_list, columns=['Date', 'Tweets'])
result
# Out:
#                         Date  \
# 0  2021-03-15 01:01:29+00:00
# 1  2021-03-15 01:05:33+00:00
# 2  2021-03-15 01:25:21+00:00
# 3  2021-03-15 01:27:17+00:00
# 4  2021-03-15 01:29:43+00:00
# ..                       ...
# 25 2021-12-31 21:17:46+00:00
# 26 2021-12-31 21:48:33+00:00
# 27 2021-12-31 22:28:16+00:00
# 28 2021-12-31 22:49:25+00:00
# 29 2021-12-31 23:27:51+00:00
#
#                                                Tweets
# 0   This could be my parents, my family.... #StopA...
# 1   Jeremy Lin is right tho \n\nBlack men like alw...
# 2   Someone sent me pics from this ramen restauran...
# 3   I really wish I could have been there yesterda...
# 4   #StopAAPIHate #StopAsianHate https://t.co/KUWZ...
# ..                                                ...
# 25  @Charlen98749545 @Sc0ttSDr3d @GryKngBlakState ...
# 26  1/ @ProfJanelleWong, political scientist &amp;...
# 27  Let’s make 2022 a year of kindness, diversity,...
# 28  @kevskewl @philanderwicks @Charlen98749545 @Sc...
# ...

# %% [markdown]
# # query #blacklivesmatter tweets

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list 
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#blacklivesmatter since:2020-05-24 until:2021-01-01 min_faves:3 exclude:retweets','corona lang:en').get_items()):
    tweets_list.append([tweet.date,  tweet.content]) #tweet.id

# %%
result= pd.DataFrame(tweets_list, columns=['Date', 'Tweets'])
